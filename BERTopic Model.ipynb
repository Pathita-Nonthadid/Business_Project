# %%
# !pip install bertopic
# !pip install umap-learn hdbscan sentence-transformers
# Out:
# Requirement already satisfied: bertopic in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: hdbscan>=0.8.29 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (0.8.40)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (0.5.9.post2)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (2.3.1)
# Requirement already satisfied: plotly>=4.7.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (6.2.0)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (1.7.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (5.0.0)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (4.67.1)
# Requirement already satisfied: llvmlite>0.36.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from bertopic) (0.44.0)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from hdbscan>=0.8.29->bertopic) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from plotly>=4.7.0->bertopic) (2.0.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from plotly>=4.7.0->bertopic) (25.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.54.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.7.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.34.3)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.14.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.7.34)
# Requirement already satisfied: requests in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.1.5)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn>=0.5.0->bertopic) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.8.3)
# Requirement already satisfied: umap-learn in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (0.5.9.post2)
# Requirement already satisfied: hdbscan in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (0.8.40)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.6 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (1.7.1)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from hdbscan) (1.5.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers) (4.54.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers) (0.34.3)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.34)
# Requirement already satisfied: requests in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn) (0.44.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)

# %%
import pandas as pd
lemmatized = pd.read_csv("lemmatized_data.csv")
lemmatized.head()
# Out:
#                post_id              user_id  \
# 0  1907578844636393679  1810361594586738692
# 1  1907578044492968060           2736639061
# 2  1907575218501198232  1850383929829945344
# 3  1907574739964510255            449290925
# 4  1907570533836701721             23709151
#
#                                            full_text  \
# 0  This is nasty \n\nNASDAQ futures down -4.4%, S...
# 1  Investors Panic as U.S. Stock Market Plummets ...
# 2  For all the people who have absolutely no conc...
# 3  As someone who is feeling JVL levels of schade...
# 4            The fuzziest math is #TrumpTariff Math.
#
#                        created_At lang  repost_count  like_count  \
# 0  Wed Apr 02 23:40:12 +0000 2025   en             0           0
# 1  Wed Apr 02 23:37:01 +0000 2025   en             1           0
# 2  Wed Apr 02 23:25:47 +0000 2025   en             0           2
# 3  Wed Apr 02 23:23:53 +0000 2025   en             0           0
# 4  Wed Apr 02 23:14:59 +0000 2025   en             0           0
#
#                 source                                text_preprocessing1  \
# 0      Twitter Web App  This is nasty \n\nNASDAQ futures down -.%, S&a...
# 1      Twitter Web App  Investors Panic as U.S. Stock Market Plummets ...
# 2  Twitter for Android  For all the people who have absolutely no conc...
# 3  Twitter for Android  As someone who is feeling JVL levels of schade...
# 4  Twitter for Android                        The fuzziest math is  Math.
#
#                    text_preprocessing_no_punctuation  \
# 0  this is nasty \n\nnasdaq futures down  sampp f...
# 1  investors panic as us stock market plummets ov...
# 2  for all the people who have absolutely no conc...
# 3  as someone who is feeling jvl levels of schade...
# 4                         the fuzziest math is  math
#
#                                    text_no_stopwords  \
# 0  nasty nasdaq futures sampp futures tariff news...
# 1  investors panic stock market plummets trumps t...
# 2  people absolutely concept tariff amp differs g...
# 3  feeling jvl levels schadenfreude let just say ...
# 4                                 fuzziest math math
#
#                                      text_lemmatized
# 0  nasty nasdaq future sampp future tariff news h...
# 1  investor panic stock market plummet trump tari...
# 2  people absolutely concept tariff amp differs g...
# 3  feel jvl level schadenfreude let just say happ...
# 4                                    fuzzy math math

# %%
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer

# Set all models
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')
hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Custom vectorizer
vectorizer_model = CountVectorizer(min_df=10) # ignoring words that appear less than 10 times
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    calculate_probabilities=True,
    verbose=True
)

# %%
docs = lemmatized['text_lemmatized'].tolist()
# Filter out any non-string values from the docs list
docs = [str(doc) for doc in docs if isinstance(doc, str)]

# Print the number of documents and a sample
print(f"Number of documents after filtering: {len(docs)}")
if len(docs) > 0:
    print("Sample documents:")
    for i, doc in enumerate(docs[:5]): # Print the first 5 documents
        print(f"{i+1}: {doc}")
else:
    print("No documents remaining after filtering.")
# Out:
# Number of documents after filtering: 22379
# Sample documents:
# 1: nasty nasdaq future sampp future tariff news hold nvda puts deep money tomorrow close bear eat good week spy
# 2: investor panic stock market plummet trump tariff plan
# 3: people absolutely concept tariff amp differs gst mark simple understand
# 4: feel jvl level schadenfreude let just say happy birthday
# 5: fuzzy math math

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2025-08-20 03:10:01,519 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 700/700 [00:33<00:00, 21.05it/s]
# 2025-08-20 03:10:34,970 - BERTopic - Embedding - Completed ✓
# 2025-08-20 03:10:34,970 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-08-20 03:10:48,248 - BERTopic - Dimensionality - Completed ✓
# 2025-08-20 03:10:48,250 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-08-20 03:11:26,827 - BERTopic - Cluster - Completed ✓
# 2025-08-20 03:11:26,847 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-08-20 03:11:27,074 - BERTopic - Representation - Completed ✓

# %%
freq = topic_model.get_topic_info(); freq.head(11)
# Out:
#     Topic  Count                                    Name  \
# 0      -1   9379            -1_trump_tariff_china_market
# 1       0   1552         0_pay_country_importer_consumer
# 2       1    652      1_china_chinese_additional_beijing
# 3       2    457              2_china_chinese_pay_import
# 4       3    380  3_canada_canadian_liberal_conservative
# 5       4    355          4_india_indian_ceasefire_offer
# 6       5    346         5_movie_outside_produce_foreign
# 7       6    318                6_inflation_cpi_low_rate
# 8       7    258         7_japan_japanese_car_negotiator
# 9       8    258            8_trump_man_tariff_president
# 10      9    241                    9_amp_one_create_buy
#
#                                        Representation  \
# 0   [trump, tariff, china, market, war, like, trad...
# 1   [pay, country, importer, consumer, product, co...
# 2   [china, chinese, additional, beijing, trump, w...
# 3   [china, chinese, pay, import, war, good, produ...
# 4   [canada, canadian, liberal, conservative, elec...
# 5   [india, indian, ceasefire, offer, deal, claim,...
# 6   [movie, outside, produce, foreign, industry, a...
# 7   [inflation, cpi, low, rate, expect, fed, feed,...
# 8   [japan, japanese, car, negotiator, auto, negot...
# 9   [trump, man, tariff, president, orange, plane,...
# 10  [amp, one, create, buy, supply, job, cost, sav...
#
#                                   Representative_Docs
# 0   [trump tariff kill market continue lie pay imp...
# 1   [bizarre he brag tariff american consumer pay ...
# 2   [china humiliates trump tariff war, wowww chin...
# 3   [consumer pay tariff chinese good amp chinese ...
# 4   [ummm canada tariff import country unless cana...
# 5   [clear message hindutuva rascal india superpow...
# 6   [trump tariff foreign movie make movie thing g...
# 7   [s inflation low feed aint look current inflat...
# 8   [charge tariff go japan, japan zerotariff poli...
# 9   [tariff trump, tariff trump, dumo tariff trump...
# 10  [tariff amp tax troglodyte, amp trump photo op...

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('pay', 0.013334295065807302),
#  ('country', 0.012449803364349234),
#  ('importer', 0.010778419366984298),
#  ('consumer', 0.00995299587417649),
#  ('product', 0.008776666830487244),
#  ('cost', 0.008672520575505622),
#  ('tax', 0.008111438751791059),
#  ('import', 0.007230246265084042),
#  ('citizen', 0.007158418979535831),
#  ('dont', 0.007140108910286662)]

# %%
import plotly.io as pio
from IPython.display import HTML 

fig_umap = topic_model.visualize_topics(top_n_topics=10)
HTML(fig_umap.to_html(include_plotlyjs="cdn"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="02d9bb7a-d8f3-4fd0-b4ab-2e4749cb22e9" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("02d9bb7a-d8f3-4fd0-b4ab-2e4749cb22e9")) {                    Plotly.newPlot(                        "02d9bb7a-d8f3-4fd0-b4ab-2e4749cb22e9",                        [{"customdata":[[0,"pay | country | importer | consumer | product",1552],[1,"china | chinese | additional | beijing | trump",652],[2,"china | chinese | pay | import | war",457],[3,"canada | canadian | liberal | conservative | election",380],[4,"india | indian | ceasefire | offer | deal",355],[5,"movie | outside | produce | foreign | industry",346],[6,"inflation | cpi | low | rate | expect",318],[7,"japan | japanese | car | negotiator | auto",258],[8,"trump | man | tariff | president | orange",258],[9,"amp | one | create | buy | supply",241]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":{"dtype":"i2","bdata":"EAaMAskBfAFjAVoBPgECAQIB8QA="},"sizemode":"area","sizeref":0.97,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f4","bdata":"U01eQS+HSUHyc1RBAHNhQRqqZEFA2UxBqZI\u002fQUw7cEFZikVByAtmQQ=="},"xaxis":"x","y":{"dtype":"f4","bdata":"yDx\u002fwAunhsAALIrAu66dwNzRhsByMkPAJAhFwNXuk8BrwmHAQkFhwA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1 ...

# %%
fig_bar = topic_model.visualize_barchart(top_n_topics=10)
HTML(fig_bar.to_html(include_plotlyjs="cdn"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="cec6e2a7-649f-49bc-9d90-3a3e21cf24a0" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cec6e2a7-649f-49bc-9d90-3a3e21cf24a0")) {                    Plotly.newPlot(                        "cec6e2a7-649f-49bc-9d90-3a3e21cf24a0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008776666830487244,0.00995299587417649,0.010778419366984298,0.012449803364349234,0.013334295065807302],"y":["product  ","consumer  ","importer  ","country  ","pay  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007221017390194234,0.007411533034017419,0.008462079839328824,0.014353244595173857,0.02491562691313106],"y":["trump  ","beijing  ","additional  ","chinese  ","china  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008655485380117008,0.009052822927490236,0.011419265296053065,0.021687434905861933,0.025702271557919744],"y":["war  ","import  ","pay  ","chinese  ","china  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.007428819796314753,0.007460260594487949,0.007817808407112877,0.04151951767869798,0.051188844760193114],"y":["election  ","conservative  ","liberal  ","canadian  ","canada  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0096401161033593,0.01075869233018102,0.014659272696876172,0.033154990355458665,0.08984047943357538],"y":["deal  ","offer  ","ceasefire  ","indian  ","india  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.025281829764644794,0.03076280219003149,0.035420263424551006,0.04463564504185723,0.11852900398795417],"y":["industry  ","foreign  ","produce  ","outside  ","movie  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.011624485749471234,0.012286417565601873,0.012473203630693408,0.021167727121564638,0.07607842759421339],"y":["expect  ","rate  ","low  ","cpi  ","inflation  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.010573984781576791,0.012653582679900285,0.022001333095427827,0.05163792221526653,0.1249173007402243],"y":["auto  ","negotiator  ","car  ","japanese  ","japan  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008821014171865536,0.009898509520420715,0.01052835150165948,0.011961778730029739,0.01546811935194405],"y":["orange  ","president  ","tariff  ","man  ","trump  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.0052236320727382934,0.005680129445872583,0.0062902719813701415,0.0074675562718775484,0.05928072918981966],"y":["supply  ","buy  ","create  ","one  ","amp  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outline ...

# %%
from gensim.models import CoherenceModel
from gensim import corpora

# Tokenize
tokenized_text = [doc.split() for doc in docs]

# Extract topic words from BERTopic model
topic_words = [ [word for word, _ in topic_model.get_topic(i)] for i in range(len(set(topics)) - 1) ]

# Dictionary and corpus for gensim
id2word = corpora.Dictionary(tokenized_text)
corpus = [id2word.doc2bow(text) for text in tokenized_text]

# Coherence model
coherence_model = CoherenceModel(
    topics=topic_words,
    texts=tokenized_text,
    dictionary=id2word,
    coherence='c_v'
)

coherence_score = coherence_model.get_coherence()
print(f"BERTopic c_v coherence score: {coherence_score:.4f}")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERTopic c_v coherence score: 0.5560

# %%
# Get the most 10 probable words for each topic
topics = topic_model.get_topic_info()

# Print a formatted table of topics
print("\nTopic ID | Count | Keywords")
print("-" * 80)
for _, row in topics.iterrows():
    # Get first 5 keywords from representation list
    keywords = ", ".join(row["Representation"])
    print(f"{row['Topic']:8d} | {row['Count']:5d} | {keywords}")
# Out:
# Topic ID | Count | Keywords
# --------------------------------------------------------------------------------
#       -1 |  9379 | trump, tariff, china, market, war, like, trade, economy, go, just
#        0 |  1552 | pay, country, importer, consumer, product, cost, tax, import, citizen, dont
#        1 |   652 | china, chinese, additional, beijing, trump, war, win, deal, good, xi
#        2 |   457 | china, chinese, pay, import, war, good, product, export, sell, importer
#        3 |   380 | canada, canadian, liberal, conservative, election, state, st, free, hurt, government
#        4 |   355 | india, indian, ceasefire, offer, deal, claim, trade, reciprocal, nation, report
#        5 |   346 | movie, outside, produce, foreign, industry, announces, production, president, die, land
#        6 |   318 | inflation, cpi, low, rate, expect, fed, feed, price, impact, data
#        7 |   258 | japan, japanese, car, negotiator, auto, negotiation, minister, giant, talk, ton
#        8 |   258 | trump, man, tariff, president, orange, plane, slap, donald, idea, declare
#        9 |   241 | amp, one, create, buy, supply, job, cost, save, need, chain
#       10 |   222 | russia, ukraine, putin, russian, sanction, end, war, oil, list, peace
#       11 |   218 | walmart, eat, price, absorb, cost, retailer, target, raise, warn, profit
#       12 |   203 | powell, rate, chair, feed, inflation, steady, reserve, cut, hold, uncertainty
#       13 |   190 | court, appeal, block, rule, authority, international, judge, federal, emergency, legal
#       14 |   175 | quota, canada, usmca, exceed, farmer, apply, product, canadian, charge, applies
#       15 |   148 | carney, mark, canada, team, election, canadian, crisis, liberal, pm, counter
#       16 |   147 | debt, deficit, trillion, doge, cut, national, tax, revenue, spending, spend
#       17 |   146 | crypto, btc, market, dip, volatility, bounce, july, bull, news, react
#       18 |   145 | mexico, canada, usmca, steel, water, illegals, auto, car, build, flag
#       19 |   129 | war, win, start, lose, fold, trump, stop, peace, xi, loser
#       20 |   125 | apple, iphones, threaten, phone, cook, manufacture, tech, threat, aapl, maker
#       21 |   120 | steel, aluminum, double, announce, industry, metal, import, increase, raise, friday
#       22 |   119 | tax, billionaire, income, wealthy, cut, american, pay, family, poor, increase
#       23 |   115 | eu, european, europe, union, billion, break, propose, average, germany, worth
#       24 |   114 | auto, car, ford, vehicle, production, plant, part, manufacturer, ceo, model
#       25 |   112 | vietnam, golf, approve, course, proposal, glad, asian, huge, china, deficit
#       26 |   109 | uk, starmer, deal, sign, pm, new, britain, trade, export, surplus
#       27 |   105 | amazon, cost, hostile, show, call, white, political, product, upset, exit
#       28 |   100 | policy, strategy, plan, national, economic, bold, donald, idea, trump, analysis
#       29 |    99 | australia, surplus, defence, export, free, deficit, agreement, trade, tumble, buy
#       30 |    98 | uschina, truce, london, tension, talk, dispute, trade, ahead, reset, amid
#       31 |    91 | maga, cult, magas, biden, lie, red, know, truth, promise, right
#       32 |    87 | uh, lol, right, huh, tire, happen, false, oh, apparently, win
#       33 |    84 | pause, day, july, delay, extend, announce, end, wait, percent, reciprocal
#       34 |    83 | taco, tuesday, lmao, bullshit, street, week, wall, ignorant, live, dumb
#       35 |    82 | lie, claim, liar, fact, check, false, grok, number, know, record
#       36 |    79 | war, history, wasnt, affect, world, consequence, economy, ally, planet, global
#       37 |    78 | farmer, farm, john, bankrupt, term, taxpayer, cost, food, cripple, jd
#       38 |    76 | israel, sanction, support, tweet, bro, war, vietnam, ally, debacle, lose
#       39 |    74 | paul, senator, vote, agenda, power, republican, authority, congress, favor, democrat
#       40 |    70 | revenue, billion, announces, wow, replace, count, massive, top, duty, claim
#       41 |    68 | drug, stop, border, ccp, didnt, incentive, baseline, illegal, china, option
#       42 |    68 | eu, europe, european, union, threaten, donald, recommend, threat, retaliate, refuse
#       43 |    67 | sampp, nasdaq, dow, future, record, stock, index, gain, rally, tech
#       44 |    67 | elon, tesla, sink, doge, trust, process, step, expert, money, have
#       45 |    66 | iran, nuclear, israel, week, failure, distract, skyrocket, debacle, day, bomb
#       46 |    66 | chicken, taco, threat, rebound, wall, theory, describe, street, tumble, delay
#       47 |    65 | congress, act, power, law, authority, constitution, section, executive, exceed, expansion
#       48 |    65 | musk, elon, tesla, ev, insult, criticize, beautiful, trumps, dispute, plan
#       49 |    59 | spy, qqq, nasdaq, spx, rally, tsla, nvda, earnings, focus, daily
#       50 |    59 | gold, asset, usd, stable, dollar, luxury, reserve, fall, british, downgrade
#       51 |    59 | drug, exception, price, company, loom, threat, skyrocket, risk, expert, invest
#       52 |    58 | digital, canada, service, tech, announce, talk, optimism, canadian, tax, immediately
#       53 |    58 | india, apple, iphones, cook, shift, production, threaten, cheap, supply, chain
#       54 |    55 | island, heard, population, hear, slap, pt, territory, treaty, figure, tarrif
#       55 |    55 | insider, trading, announcement, stock, manipulation, manipulate, meta, million, prior, james
#       56 |    54 | august, pause, extend, chinese, st, day, good, certain, break, taco
#       57 |    52 | toy, kid, child, suggest, manufacturer, alert, baby, kill, afford, acknowledge
#       58 |    51 | apple, iphones, cheap, phone, cost, production, manufacture, pay, assume, bc
#       59 |    51 | stock, sharply, dow, plunge, panic, market, reprieve, street, crash, client
#       60 |    50 | bond, yield, treasury, debt, market, crisis, sell, rise, narrative, folk
#       61 |    46 | cut, rate, fed, feed, september, bank, labour, later, pc, glad
#       62 |    45 | cave, predict, fox, communist, beijing, art, youre, spy, master, traitor
#       63 |    44 | delay, eu, future, july, rally, rise, stock, european, pause, surge
#       64 |    44 | negotiation, deal, agreement, arent, really, negotiator, sign, leverage, partner, secretary
#       65 |    44 | delay, july, european, union, eu, extension, june, deadline, request, agree
#       66 |    44 | african, slam, export, dr, shipment, ongoing, opportunity, south, country, nation
#       67 |    41 | fell, opportunity, buying, provide, implement, love, follow, month, stock, great
#       68 |    40 | minister, prime, partnership, urge, pm, financial, reveal, technology, strengthen, avoid
#       69 |    38 | steel, margin, domestic, ton, create, demand, use, mean, high, raise
#       70 |    36 | vat, sale, equal, eu, apply, charge, subsidy, applies, tax, import
#       71 |    35 | labor, slave, retail, vietnam, factory, pay, custom, wear, reliance, warn
#       72 |    35 | florida, perfectly, plummet, farmer, cause, policy, pick, price, good, react
#       73 |    35 | democrat, midterm, party, republican, dems, vote, issue, senate, immigration, support
#       74 |    35 | platform, youve, fund, scam, recovery, user, message, withdraw, hostage, crypto
#       75 |    34 | deadline, extend, july, loom, wednesday, critical, push, offer, best, extension
#       76 |    34 | small, business, tourist, owner, consider, baby, family, busy, visit, exemption
#       77 |    34 | electronics, exempt, exemption, semiconductor, temporary, phone, lutnick, institute, print, recently
#       78 |    34 | navarro, peter, lutnick, bessent, wsj, rush, schedule, garbage, century, serve
#       79 |    33 | rare, earth, mineral, beijing, lift, control, critical, material, chip, export
#       80 |    32 | ukraine, israel, iran, war, russia, peace, second, intention, bomb, easily
#       81 |    32 | letter, send, partner, set, deadline, rate, week, july, unilateral, say
#       82 |    32 | grow, build, produce, commerce, sec, lutnick, assemble, america, walmart, weve
#       83 |    31 | deficit, trade, shouldve, fiscal, narrow, ramp, large, fan, reduce, escalation
#       84 |    31 | pause, day, announces, china, exclude, levy, suspend, reciprocal, raise, yesterday
#       85 |    31 | light, data, network, service, die, supply, affect, share, increase, useless
#       86 |    31 | poll, approval, rating, number, approve, find, priority, focus, trip, reflect
#       87 |    31 | iran, russia, close, strength, china, nuclear, conduct, east, regime, military
#       88 |    31 | money, pay, float, immigrant, figure, team, promise, check, prof, dig
#       89 |    31 | shelf, retailer, warn, major, store, brace, shipment, retail, port, collapse
#       90 |    30 | nasdaq, soar, sampp, rally, pause, temporary, point, spark, market, drama
#       91 |    30 | effect, impact, plunge, affect, large, early, hurt, relief, industry, follower
#       92 |    30 | plane, gift, jet, john, trip, corruption, piece, million, discuss, east
#       93 |    30 | bidens, hurt, biden, economy, disaster, idiotic, he, tantrum, well, growth
#       94 |    30 | price, pay, want, show, worker, american, profit, ok, dont, admin
#       95 |    29 | manufacturing, manufacture, outsource, worker, job, plant, chip, advance, bring, immigrant
#       96 |    29 | week, unilateral, set, rate, hell, say, thought, detail, press, walk
#       97 |    28 | korea, south, protection, north, alliance, japan, building, president, child, early
#       98 |    28 | car, eu, germany, german, europe, vat, european, equal, build, add
#       99 |    28 | podcast, listen, equipment, tune, join, insight, live, mention, follower, vibe
#      100 |    28 | record, treasury, reach, april, revenue, billion, surplus, boost, budget, collect
#      101 |    28 | egg, grocery, price, expert, equal, gas, recover, fact, balance, significant
#      102 |    27 | rep, jump, stock, net, insider, trading, congress, cash, worth, join
#      103 |    27 | jet, return, plane, amid, part, reprieve, china, war, earlier, air
#      104 |    27 | sanction, response, secure, beijing, monday, zero, tantrum, united, daily, threaten
#      105 |    27 | sentiment, consumer, expectation, confidence, retail, sale, drop, fell, rebound, june
#      106 |    27 | respect, threat, eu, finance, german, talk, base, minister, chief, union
#      107 |    27 | cut, snap, tax, rich, fund, wealthy, million, obama, poor, protect
#      108 |    27 | lutnick, howard, secretary, commerce, bessent, scott, treasury, story, shock, sec
#      109 |    26 | liberation, day, expose, week, dollar, july, deadline, weekend, shouldve, ugly
#      110 |    26 | aluminum, steel, canadian, canada, city, resource, depend, ton, trading, producer
#      111 |    25 | destroy, weak, different, thanks, strong, evil, repeat, common, wild, victory
#      112 |    25 | revenue, billion, monthly, skyrocket, june, collect, month, bn, number, money
#      113 |    25 | california, state, democrat, governor, funding, rest, large, washington, yes, nation
#      114 |    24 | beef, australia, quality, blow, ban, usa, senate, best, fake, well
#      115 |    24 | deportation, deport, illegal, illegals, matter, process, imposition, sanction, inside, constitution
#      116 |    23 | rebound, equity, stock, fear, trader, investor, volatility, market, rise, rally
#      117 |    23 | protest, flag, traitor, ice, amp, loser, white, terrorist, mask, dictator
#      118 |    23 | east, middle, relocate, city, land, hostage, peace, similar, build, weapon
#      119 |    23 | phone, china, guess, exemption, build, interest, probably, excellent, summary, version
#      120 |    22 | uncertainty, activity, beat, estimate, despite, street, wall, factor, manufacturing, invest
#      121 |    22 | lie, china, cheat, negotiate, call, bc, fee, speak, biden, plus
#      122 |    22 | panic, fear, shelf, reality, travel, truly, shut, bomb, chaos, expert
#      123 |    21 | asian, asia, south, korea, energy, amid, various, cooperation, effort, balance
#      124 |    21 | stock, market, crash, august, hint, recover, china, tweet, jump, chinas
#      125 |    21 | tesla, car, ev, chinese, option, well, manufacturer, vehicle, affordable, cheap
#      126 |    21 | talk, official, meet, bessent, begin, hope, secretary, treasury, progress, senior
#      127 |    21 | stock, market, plummet, popular, crash, record, poll, soar, trigger, happy
#      128 |    21 | uk, british, plant, starmer, beef, car, quota, vehicle, chairman, immediately
#      129 |    21 | apple, phone, iphones, private, label, impossible, build, payment, own, google
#      130 |    21 | angry, struggle, government, small, death, thousand, wealth, compare, im, laugh
#      131 |    21 | ban, achieve, complicate, barely, barrier, sweep, discus, california, retaliation, miss
#      132 |    21 | growth, bank, result, forecast, gdp, economic, annual, world, quarter, policy
#      133 |    20 | tantrum, crack, cry, fault, throw, damage, continue, amidst, quit, smarter
#      134 |    20 | chaos, mess, strategy, approval, rating, economic, article, decade, economist, reality
#      135 |    20 | xi, backfire, tension, phone, unilateral, mineral, chinese, despite, president, visit
#      136 |    20 | news, bloomberg, immediately, nbc, county, awful, talk, council, agent, saturday
#      137 |    20 | car, part, build, thousand, plant, inventory, maker, gt, industry, vehicle
#      138 |    20 | shrink, budget, sweep, deficit, trillion, office, household, accord, reduce, overall
#      139 |    20 | formula, deficit, math, calculate, divide, household, use, charge, reciprocal, export
#      140 |    19 | network, art, fight, na, gon, expose, life, identify, conduct, associate
#      141 |    19 | covid, credit, death, related, course, reckless, bidens, rating, plus, crisis
#      142 |    19 | vehicle, car, canada, auto, usmca, canadian, tesla, nafta, subsidize, model
#      143 |    19 | wash, bag, machine, bn, factor, corporation, aluminum, northern, middle, excellent
#      144 |    19 | recession, chance, rest, crazy, economist, lawmaker, mock, root, kiss, inevitable
#      145 |    18 | downgrade, rating, credit, yield, yr, bond, doge, spx, debt, fiscal
#      146 |    18 | absolute, start, guy, wipe, argue, he, cabinet, americas, genius, nice
#      147 |    18 | panel, asian, asia, energy, imposes, correct, vehicle, kill, competitor, manufacturer
#      148 |    18 | beef, uk, standard, allow, tarifffree, growth, feed, argument, car, ban
#      149 |    18 | punish, disagree, doesnt, as, country, lot, dont, youre, expert, dig
#      150 |    18 | steel, uk, british, aluminum, starmer, exemption, usuk, bbc, aluminium, exempt
#      151 |    17 | tds, suffer, bessent, manipulation, chair, scott, weak, incredibly, administration, register
#      152 |    17 | ally, friend, partner, nato, neighbour, ok, defense, access, hand, rule
#      153 |    17 | ship, port, surge, spike, april, week, volume, rush, shipping, halt
#      154 |    17 | eu, european, july, union, june, deadline, pc, leader, weigh, st
#      155 |    16 | eu, defence, spending, urge, link, story, understand, rule, strategically, click
#      156 |    16 | epstein, file, distraction, musk, release, tesla, boycott, info, bs, chaos
#      157 |    16 | steel, japanese, japan, approve, invest, strike, purchase, control, worker, portion
#      158 |    15 | dollar, currency, decline, usd, worst, index, sink, reserve, slump, low
#      159 |    15 | eu, prime, conference, minister, host, pm, meet, vance, europe, sure
#      160 |    15 | imagine, party, washington, national, hard, maga, month, tax, send, american
#      161 |    15 | loophole, ship, halt, directly, price, hike, customer, stop, shopping, ahead
#      162 |    15 | car, canada, float, reuters, part, canadian, uh, say, star, luxury
#      163 |    15 | crash, recovery, cave, market, brain, program, attack, easy, ill, card
#      164 |    15 | time, change, absurd, nut, jan, mandate, announcement, knew, recovery, ass
#      165 |    15 | stream, potentially, shot, debate, break, imposes, donald, style, swift, spot
#      166 |    15 | hi, shift, bite, sharp, group, port, signal, join, certainty, update
#      167 |    14 | spike, effect, treasury, video, report, revenue, policy, raise, response, abc
#      168 |    14 | oil, fuel, crude, settle, production, concerned, mixed, demand, news, remain
#      169 |    14 | exporter, textile, indian, asian, link, east, export, opportunity, comment, sector
#      170 |    14 | knee, advice, hole, road, honestly, clue, yes, dont, werent, thing
#      171 |    14 | expose, republic, trumps, lie, talk, red, press, new, china, wear
#      172 |    14 | amaze, opportunity, buying, provide, love, follow, drop, month, stock, policy
#      173 |    14 | bluff, reshape, flop, badly, chaos, flip, laugh, call, hand, ive
#      174 |    14 | depression, act, great, raise, enact, learn, past, sharply, aid, pass
#      175 |    13 | negotiation, negotiator, security, amidst, pact, neighbour, tension, reminder, interested, partnership
#      176 |    13 | prof, currency, criticize, manipulation, weapon, finance, listen, meeting, poor, fix
#      177 |    13 | growth, inflate, alienate, mask, shortterm, gdp, voter, debt, fiscal, bet
#      178 |    13 | vance, jd, forward, disaster, wear, enrich, style, sir, foot, upcoming
#      179 |    13 | drug, loophole, flood, close, fat, dare, daily, cripple, podcast, isolate
#      180 |    13 | scott, secretary, bessent, treasury, unsustainable, summit, substantial, progress, reportedly, tuesday
#      181 |    13 | home, slump, component, worsen, key, canadian, immigration, new, material, bc
#      182 |    13 | small, exporter, slash, squeeze, package, shipment, spike, offset, drop, seek
#      183 |    13 | domestically, consumption, grant, wealthy, meet, grow, breakdown, exemption, pre, national
#      184 |    13 | loose, financial, plunge, fund, wealth, investor, stock, short, instance, grip
#      185 |    13 | angry, wreck, scam, backfire, republic, smartnews, walmart, read, podcast, cash
#      186 |    13 | article, story, link, here, read, suspect, match, add, wow, google
#      187 |    13 | ruin, harris, garbage, relation, deport, right, wasnt, wouldnt, control, crash
#      188 |    13 | carney, sit, monday, ahead, continue, meeting, summit, journal, determine, start
#      189 |    13 | read, comment, related, couple, previous, piece, link, worth, interest, share
#      190 |    12 | finalize, lutnick, howard, commerce, secretary, understand, reach, month, ago, sign
#      191 |    12 | explain, trash, isolate, corruption, debacle, chart, approval, ccp, measure, suffer
#      192 |    12 | alert, asset, fund, disappear, scam, stay, scheme, protect, steal, investor
#      193 |    12 | uncertainty, wouldnt, heres, entirely, abroad, criticize, building, rollout, ability, chaos
#      194 |    12 | save, earn, collapse, america, day, billion, financial, trillion, bring, jet
#      195 |    12 | harm, gdp, produce, poor, get, face, export, textile, tiny, deficit
#      196 |    12 | revenue, collect, source, april, specifically, past, surge, indicate, historic, billion
#      197 |    11 | bloomberg, economics, regime, trillion, job, lose, world, loss, economy, cost
#      198 |    11 | math, formula, follower, unveil, resistance, et, amount, carry, theirs, extremely
#      199 |    11 | ccp, register, chinese, influence, oppose, tarifffree, scheme, dems, covid, nearly
#      200 |    11 | concern, amid, shrink, economy, year, time, primarily, quarter, false, imposes
#      201 |    11 | corrupt, gdp, mandate, cut, revenue, ai, energy, doge, wrong, inflation
#      202 |    11 | negotiation, talk, reach, interested, night, previously, substantial, finalize, pivot, withdraw
#      203 |    11 | back, russian, russia, mr, putin, oil, gas, golf, impose, ukraine
#      204 |    11 | holy, water, select, wall, mock, channel, jd, city, immigrant, build
#      205 |    10 | face, billionaire, economist, scam, rake, meltdown, warn, criticize, complete, decision
#      206 |    10 | fox, worsen, republic, fiasco, news, expose, mislead, repeatedly, site, la
#      207 |    10 | weight, slump, aggressive, cabinet, debacle, global, donald, meeting, constant, feel
#      208 |    10 | file, york, state, administration, argue, general, challenge, new, list, regulate
#      209 |    10 | billion, million, government, man, dollar, join, collect, politico, fund, revenue

# %%
# Group by Topic and sample 5 random documents from each group
topic_info = topic_model.get_topic_info()
valid_topics = topic_info.loc[topic_info["Topic"] != -1, "Topic"].tolist()
top_docs_rows = []
if "probs" not in locals() or probs is None:
    # fallback: representative docs only (no prob scores, no index mapping)
    for t in valid_topics:
        reps = topic_model.get_representative_docs(t) or []
        for rank, doc in enumerate(reps[:5], 1):
            top_docs_rows.append({
                "topic_id": t,
                "rank": rank,
                "prob": None,
                "doc_index": None,
                "document": doc,
                "full_text": None  # cannot map back reliably here
            })
else:
    probs = np.asarray(probs)
    for t in valid_topics:
        if t < probs.shape[1]:
            top_idx = np.argsort(probs[:, t])[::-1][:5]
            for rank, i in enumerate(top_idx, 1):
                top_docs_rows.append({
                    "topic_id": t,
                    "rank": rank,
                    "prob": float(probs[i, t]),
                    "doc_index": int(i),
                    "document": docs[i],         # preprocessed
                    "full_text": lemmatized.full_text[i]    # raw/original text
                })

df_top_docs_bt = pd.DataFrame(top_docs_rows)
df_top_docs_bt.to_csv("bertopic_top5_docs_per_topic.csv", index=False)

# %%
import numpy as np

# Clean, aligned inputs
df = lemmatized.copy()
df["txt"] = df["text_lemmatized"].astype(str).str.strip()

# Parse X timestamps like: Tue Jun 24 22:24:33 +0000 2025
df["ts"] = pd.to_datetime(
    df["created_At"],
    format="%a %b %d %H:%M:%S %z %Y",   # match your data
    errors="coerce",
    utc=True
).dt.tz_convert(None)                    # drop timezone

# keep valid rows only
df = df[df["ts"].notna() & df["txt"].ne("")]

docs       = df["txt"].tolist()
timestamps = df["ts"].tolist()           # keep full datetime

# Get per-document TOPIC IDS that match THESE docs 
assigned_topics, _ = topic_model.transform(docs)   # ints: [2, 7, 1, ...]

# Safety checks
print("lens:", len(docs), len(assigned_topics), len(timestamps))
assert len(docs) == len(assigned_topics) == len(timestamps)
assert all(isinstance(t, (int, np.integer)) for t in assigned_topics), "topics must be ints"

# Topics over time 
tot = topic_model.topics_over_time(
    docs=docs,
    topics=assigned_topics,              
    timestamps=timestamps,
    nr_bins=20                           
)
# Out:
# Batches: 100%|██████████| 700/700 [00:32<00:00, 21.86it/s]
# 2025-08-20 03:13:23,706 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# /opt/anaconda3/envs/bertopic-env/lib/python3.10/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-08-20 03:13:33,775 - BERTopic - Dimensionality - Completed ✓
# 2025-08-20 03:13:33,776 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-08-20 03:13:34,522 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2025-08-20 03:14:12,506 - BERTopic - Probabilities - Completed ✓
# 2025-08-20 03:14:12,508 - BERTopic - Cluster - Completed ✓
# lens: 22392 22392 22392
# 20it [00:01, 18.53it/s]

# %%
fig_overtime = topic_model.visualize_topics_over_time(tot, top_n_topics=10)
HTML(fig_overtime.to_html(include_plotlyjs="cdn"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="a2812bc8-16eb-4e76-9ceb-e98c3b45fb24" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a2812bc8-16eb-4e76-9ceb-e98c3b45fb24")) {                    Plotly.newPlot(                        "a2812bc8-16eb-4e76-9ceb-e98c3b45fb24",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: country, ok, reciprocal, pay, dont","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: country, importer, product, exporter, charge","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: country, item, consumer, product, pay","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: switch, pay, country, citizen, product","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: income, country, pay, wait, tax","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: country, income, pay, importer, product","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: importer, country, pay, product, item","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: item, pay, country, ok, price","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, importer, consumer, bn, citizen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: importer, custom, country, work, pay","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, importer, company, cost, country","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, importer, cost, hurt, product","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ok, country, pay, importer, consumer","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, company, country, mean, dont","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: revenue, country, consumer, pay, tax","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, consumer, itll, tax, importer","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, govt, consumer, money, tax","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, importer, consumer, raw, citizen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pay, purchase, country, understand, cost","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: importer, pay, consumer, country, revenue"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_pay_country_importer_consumer","x":["2025-04-02T02:23:59.136000000","2025-04-06T17:32:58.200000000","2025-04-11T06:31:11.400000000","2025-04-15T19:29:24.600000000","2025-04-20T08:27:37.800000000","2025-04-24T21:25:51.000000000","2025-04-29T10:24:04.200000000","2025-05-03T23:22:17.400000000","2025-05-08T12:20:30.600000000","2025-05-13T01:18:43.800000000","2025-05-17T14:16:57.000000000","2025-05-22T03:15:10.200000000","2025-05-26T16:13:23.400000000","2025-05-31T05:11:36.600000000","2025-06-04T18:09:49.800000000","2025-06-09T07:08:03.000000000","2025-06-13T20:06:16.200000000","2025-06-18T09:04:29.400000000","2025-06-22T22:02:42.600000000","2025-06-27T11:00:55.800000000"],"y":{"dtype":"i1","bdata":"WSUoNStNaDBILDonODA+MiMpMU4="},"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: beijing, truly, response, china, usa","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: additional, withdraw, china, threaten, retaliatory","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: china, chinese, beijing, xi, april","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: china, chinese, escalate, suffer, welcome","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: china, play, chinese, blink, cabinet","\u00 ...
